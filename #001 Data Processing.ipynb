# %%
x = 3
print(type(x))
print(x)
print(x+1)
print(x-1)
print(x*2)
print(x**2)
x+=1
print(x)
x*=2
print(x)
y=2.5
print(type(y))
print(y, y+1, y*2, y**2)
# Out:
# <class 'int'>
# 3
# 4
# 2
# 6
# 9
# 4
# 8
# <class 'float'>
# 2.5 3.5 5.0 6.25
